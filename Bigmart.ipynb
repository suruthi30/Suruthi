# %% [markdown]
# <a href="https://colab.research.google.com/github/suruthi30/Suruthi/blob/main/Bigmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BIGMART SALES ANALYSIS

# %% [markdown]
# #DATASETS DESCRIPTIONS

# %% [markdown]
# 1. The project datasets have been divided into two the TRAIN and the TEST datasets where the former have 8523 rows and 12 coulmns and the later have 5881 rows and 11 columns.

# %% [markdown]
# 2. We could find that the target column in the train set is Item_Outlet_Sales where it is the sales of the items in the particular outputs.

# %% [markdown]
# 3.Item_Identifier-- These are set of unique values to access the items.

# %% [markdown]
# 4.Item_Weight-- Weight of the individual items.

# %% [markdown]
# 5.Item_Fat_Content--Tells about the fat content present in each items.

# %% [markdown]
# 6.Item_Visibility--The percentage of display area of the items.

# %% [markdown]
# 7.Item_Type--It is the products that are kept for sale.

# %% [markdown]
# 8.Item_MRP--The Maximum Retail Price for every item in a store.

# %% [markdown]
# 9.Outlet_Identifier--These are unique number to identify the outlets.

# %% [markdown]
# 10.Outlet_Establishment_Year--The year in which the Outlet was established.

# %% [markdown]
# 11.Outlet_Size--Th Area or the size of the outlet.

# %% [markdown]
# 12.Outlet_Location_Type--The location Type of a Outlet.

# %% [markdown]
# 13.Outlet_Type--Tells about the type whether its a super market or a grocery store.

# %%
import numpy as np
import pandas as pd


#import the required libraries for the analysis of the project.

# %% [markdown]
# #Loading the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
#mount google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from  google.colab import drive
drive.mount('/content/drive')
# Mounting my google drive to the google colab Notebook where the datasets have been uploaded already.
#so that we need not upload the dataset every time the runtime is disconnectedfrom  google.colab import drive.
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Mart Dataset/Train.csv")
#import neccessary libraries and load datasets.

# %%
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Big_Mart Dataset/Test.csv")
#import neccessary libraries and load datasets.

# %% [markdown]
# #DATA STRUCTURES AND FUNCTIONS

# %%
train.dtypes
#The function.dtypes returns the data type of each column of the dataframe.
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
test.dtypes
#The function.dtypes returns the data type of each column of the dataframe.
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
train.isnull().sum()
#The function.isnull().sum() returns the number of missing values in the dataset.
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.isnull().sum()
#The function.isnull().sum() returns the number of missing values in the dataset.
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
train.describe()
#The function.decribe returns description of the data in the dataframe.
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
test.describe()
#The function.decribe returns description of the data in the dataframe.
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
train.info()
#The function.info prints the information about the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
test.info()
#The function.info prints the information about the dataframe.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
train.duplicated()
#The function.duplicated returns a series with true and false that describe which rows in the dataframe are duplicated.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
test.duplicated()
#The function.duplicated returns a series with true and false that describe which rows in the dataframe are duplicated.
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
train.columns
#The function.vertical groupings of cells on any spreadsheet.
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
test.columns
#The function.vertical groupings of cells on any spreadsheet.
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
train.head()
#The function.head returns a specified number of rows,string from the top.
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
test.head()
#The function.head returns a specified number of rows,string from the top.
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
train.tail()
#The function.tail return the first or last part of an object.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
test.tail()
#The function.tail return the first or last part of an object.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
train.shape
#where.shape returns the number of rows and columns present in the given dataset.
# Out:
# (8523, 12)

# %%
test.shape
#where.shape returns the number of rows and columns present in the given dataset.
# Out:
# (5681, 11)

# %% [markdown]
# DATA STRUCTURE AND CONTENT

# %% [markdown]
# #DATA PREPROCESSING

# %%
train['Item_Type'].value_counts()
#display vale counts for 'Item_Type'.
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
test['Item_Type'].value_counts()
#display vale counts for 'Item_Type'.
# Out:
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'.
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'.
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %% [markdown]
# #EXPLARATORY ANALYSIS

# %% [markdown]
# univariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors
#import the required libraries for the analysis of the project.

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content' , data=train)
plt.xlabel('Item_Fat_Content')
plt.show()
#plot the frequency distribution of 'Item_Fat_Content'with a 3x3 inch figure size.
#A countplot is a type of data visualization used in python.
#It is paricularly useful for visualizing the count occurences of each unique value.
#The sns.countplot function is used to create the count plot.
#The items have more low fat content and moderate regular fat content.

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Item_Type' , data=train)
plt.ylabel('Item_Type')
plt.show()
#plot the frequency countplot for 'Item_Type'.

# %%
outletsize=train['Outlet_Size'].value_counts(normalize=True)*100
explode=(0.05,00.6,0.07)
colors=('blue','black','violet')
plt.pie(outletsize,labels=outletsize.index,autopct='%1.1f%%',explode=explode,colors=colors)
plt.title('%outletsize')
plt.axis('equal')
plt.show()
#plot the piechart for 'Outlet_Size' with the equal axis.

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Type' , data=train)
plt.ylabel('Outlet_Type')
plt.show()
#plot the frequency distribution of 'Outlet_Type' with a 3x3 inch figure size.

# %% [markdown]
# supermarket type 1 is high where as supermarket type 2 is low in count when compared to others.

# %%
plt.figure(figsize=(4,4))
sns.countplot(x='Outlet_Size' , data=train)
plt.xlabel('Outlet_Size')
plt.show()
#plot the frequency distribution of 'Outlet_Size' with a 5x5 inch figure size.

# %% [markdown]
# The medium outlet size is high.small outletsize is lower than the medium ,whereas high outlet size is lower than the both medium and small

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Establishment_Year' , data=train)
plt.ylabel('Outlet_Establishment_Year')
plt.show()
#plot the frequency distribution of 'Outlet_Establishment_Year' with 4x4 inch figure size.

# %% [markdown]
# The establishment year from (1985 - 2009) is given in this graph.
# so the count is higher in the year 1985 whereas lower in the year 1998.
# And the years 1987,1997 and (1999 - 2009) are equivalent.

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Outlet_Location_Type' , data=train)
plt.ylabel('Outlet_Location_Type')
plt.show()
#plot the distribution of 'Outlet_Location_Type'with a 4x4 inch figure size.

# %% [markdown]
# Here the location type is named as tier.
# The tier 3 is higher in count.
# Whereas tier 1 is low.
# And the tier 2 is higher than the tier 1.

# %%
plt.figure(figsize=(4,4))
sns.countplot(y='Item_Type' , data=test)
plt.ylabel('Item_Type')
plt.show()
#plot the distribution for 'Item_Type' with 4x4 inch figure size.

# %% [markdown]
# In this we have plotted the graph using the test datas.
# So here the snacks have saled higher when compared to the other products

# %% [markdown]
# #To handle the missing and categorical values

# %%
# To handle the Missing and null values
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in train.columns:
    if train[col].dtype=='object'
        train[col]=le.fit_transform(train[col])
 #converting the labels into a numeric form using label encoder for the train set.

# %%
train['Outlet_Size'].dtypes
#display the datasets of 'Outlet_Size' column.
# Out:
# dtype('int64')

# %%
train.head()
#display the updated few rows of the datasets.
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            3
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
imputer=SimpleImputer(strategy='mean')
missing_columns=['Item_Weight','Outlet_Size']
train[missing_columns]=imputer.fit_transform(train[missing_columns])
#simple imputer to multiply to the strategy and to find the columns and size of the outletsize and outletcolumn.

# %%
train.isnull().sum()
##count the missing valuesin each columns of the  train set.
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
le=LabelEncoder()
for col in test.columns:
    if test[col].dtype=='object':
        test[col]=le.fit_transform(test[col])
        #converting the labels into a numeric form using label encoder for the train set.

# %%
test['Outlet_Size'].dtypes
#display the datasets of 'Outlet_Size' column.
# Out:
# dtype('int64')

# %%
test.head()
#display the updated few rows of the datasets.
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103       20.750                 1         0.007565         13
# 1             1067        8.300                 4         0.038428          4
# 2             1406       14.600                 1         0.099575         11
# 3              809        7.315                 1         0.015388         13
# 4             1184          NaN                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999            1
# 1   87.3198                  2                       2007            3
# 2  241.7538                  0                       1998            3
# 3  155.0340                  2                       2007            3
# 4  234.2300                  5                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# ...

# %%
imputer=SimpleImputer(strategy='mean')
missing_coloums=['Item_Weight','Outlet_Size']
test[missing_coloums]=imputer.fit_transform(test[missing_coloums])
#simple imputer to multiply to the strategy and to find the columns and size of the itemweight and outletsize.

# %%
test.isnull().sum()
#count the missing valuesin each columns of the  tests set.
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifying outliers')
plt.show
# Create a horizontal boxplot of numeric columns in the 'train' DataFrame to visually identify potential outliers.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The outliers exist in columns of 2,11 and 12 within the range whereas outlier in the column 1 lies outer the range.

# %%
number_columns=test.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifying outliers')
plt.show
# Create a horizontal boxplot of numeric columns in the 'test' DataFrame to visually identify potential outliers
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# In above graph, for test dataset there is only 3 outliers exists in range.

# %% [markdown]
# There is no outliers lies out of the range.

# %%
q1=np.percentile(train['Item_Outlet_Sales'], 25)
q3=np.percentile(train['Item_Outlet_Sales'], 75)
iqr=q3-q1
print('q1=',q1)
print('q3=',q3)
print('IQR=',iqr)
# Calculate and print the first quartile (Q1), third quartile (Q3), and the interquartile range (IQR) of 'Item_Outlet_Sales' in the 'train' DataFrame.
# Out:
# q1= 834.2474
# q3= 3101.2964
# IQR= 2267.049

# %%
upperlimit=q3+1.5*iqr
lowerlimit=q1-1.5*iqr
print('upperlimit',upperlimit)
print('lowerlimit',lowerlimit)
 #Calculate and print the upper and lower limits for detecting outliers using the 1.5*IQR rule..
# Out:
# upperlimit 6501.8699
# lowerlimit -2566.3261

# %% [markdown]
# Cube transformation

# %%
train['Outlet_Sales_Cube']=np.cbrt(train['Item_Outlet_Sales'])
#Computes the cube root of the sales data.

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifying outliers')
plt.show
# Selects numerical columns from the DataFrame and plots a horizontal boxplot to help identify outliers.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above graph consists of outliers in the columns of Outlet_Sales_Cube,Outlet_Type,Item_Visibility ,Item_Outlet_Size and Item_Fat_Content.

# %% [markdown]
# In the columns of 1,3,11 and 12 consists of outliers within the range whereas column 2 consists of outliers out of the range.

# %% [markdown]
# Square transformation

# %%
train['Outlet_Sales_Square']=np.sqrt(train['Item_Outlet_Sales'])
# Computes the square root of the sales data.

# %%
sns.distplot(a=train['Outlet_Sales_Square'],kde=True,rug=True)
#a=train['Outlet_Sales_square']: Specifies the data to be plotted, which in this case is the Outlet_Sales_square column from the train DataFrame.
#kde=True: Adds a Kernel Density Estimate (KDE) line to the plot, which represents the probability density function of the data.
#rug=True: Adds small vertical lines at the bottom of the plot for each data point, giving a sense of the distribution of individual data points.
# Out:
# <ipython-input-60-8544ba4d404b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Square'],kde=True,rug=True)
# <Axes: xlabel='Outlet_Sales_Square', ylabel='Density'>

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identifying outliers')
plt.show
# Selects numerical columns from the DataFrame and plots a horizontal boxplot to help identify outliers.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The above graph consists of ouliers in the columns of (1-4) and (11-12).
# The outliers in the columns of 4,11 and 12 are in their range.
# The outliers in the columns of 1,2 and 3 are out of the range.

# %% [markdown]
# Bivariate Analysis

# %%
sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
## Plots a distribution plot of 'Item_Outlet_Sales' with a kernel density estimate (KDE) and rug plot for visualization.
# Out:
# <ipython-input-62-b370abf2d6ff>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# The outliers ranging from (0-7k).

# %% [markdown]
# Whereas outliers is also present in the ranges from 8k to 13k but with the plentier amount.

# %%
sns.distplot(a=train['Outlet_Sales_Cube'],kde=True,rug=True)
## Plots a distribution plot of 'Outlet_Sales_Cube' with a kernel density estimate (KDE) and rug plot for visualization.
# Out:
# <ipython-input-63-fa659074ec58>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_Cube'],kde=True,rug=True)
# <Axes: xlabel='Outlet_Sales_Cube', ylabel='Density'>

# %% [markdown]
# The above graphical representation is similar to bell curve.

# %% [markdown]
# Here the peak point represents the higher density.

# %% [markdown]
# The outliers are ranging from 5 to 21 whereas outliers also present in the ranges of 21 to 23 in the plentier amount.

# %%
#Set the size of the figure
plt.figure(figsize=(8,8))
# Create a bar plot with 'Item_Outlet_Sales' on the x-axis and 'Item_Type' on the y-axis
sns.barplot(x='Item_Outlet_Sales',y='Item_Type',data=train).set(title='Item_Outlet_sales vs Item_Type ')
## Set the labels for the x and y axes
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('Item_Type')
#Display the plot
plt.show()

# %% [markdown]
# In the above graph seafood consists of more outliers when compared to others.

# %% [markdown]
# Multivariate analysis

# %%
# Subset the dataset to include only the relevant columns
subset = train[['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
             'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
             'Item_Outlet_Sales','Outlet_Sales_Cube']]

# Calculate the correlation matrix
corr = subset.corr()

# Create a mask for the upper triangle of the heatmap
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 8))

# Generate the heatmap with green and white colors
sns.heatmap(corr, mask=mask, annot=True, cmap=sns.diverging_palette(20, 220, n=200),
            center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Set the title and labels for the plot
ax.set_title("Correlation Heatmap", fontsize=18)
ax.set_xlabel("Features", fontsize=14)
ax.set_ylabel("Features", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# #Feature engineering

# %%
train.head()
#display the first five rows of the 'train' Dataframe.
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
train['Outlet_Age']=train['Outlet_Establishment_Year'].apply(lambda year: 2024-year)
#calculate the age of each outlet by subtracting the establishment year from 2024.
#And add it as a new column 'Outlet_Age' to the DataFrame.

# %%
train.head()
#display the first five rows of the 'train' Dataframe..
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
train=train.drop(['Item_Identifier','Item_Weight','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Sales_Square'],axis=1)
#Remove the specified columns from the 'train' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
train=train.drop(['Item_Outlet_Sales','Item_Visibility'],axis=1)
#Remove the specified columns from the 'train' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
train.head()
#display the first five rows of the 'train' DataFrame.
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 1          4  249.8092                     0            1
# 1                 2         14   48.2692                     2            2
# 2                 1         10  141.6180                     0            1
# 3                 2          6  182.0950                     2            0
# 4                 1          9   53.8614                     2            1
#
#    Outlet_Sales_Cube  Outlet_Age
# 0          15.515611          25
# 1           7.625576          15
# 2          12.800240          25
# 3           9.013888          26
# 4           9.982319          37

# %%
from sklearn.preprocessing import StandardScaler
#import standardscaler from sklearn.preprocessing for feature standardization.
#standardscaler will be used to standardize features by removing the mean and scaling to unit variation.

# %%
x=train[['Item_Fat_Content','Item_Type','Item_Type','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
y=train['Outlet_Sales_Cube']
#define the feature variable (x) and the target variable (y) for the model.
#'x' contains the columns 1,2,3,4 and 6.
#'y' contains the column 5 which is the variable we want to predict.

# %%
x.shape
#display the dimensions of the 'x' DataFrame.
# Out:
# (8523, 6)

# %%
scaler=StandardScaler()
#create an instance of standardscaler for feature standardiztion.
#this scaler will be used to normalize the features by removing the mean and scaling to unit variance.

# %%
x=scaler.fit_transform(x)
#standardize the feature variable 'x' using the standardscaler.
#this scales the feature to have a mean of 0 and a standard deviation of 1.

# %%
#display the 'x'.
print(x)
# Out:
# [[-0.57284357 -0.76647929 -0.76647929 -1.36933384 -0.25265831 -0.13954076]
#  [ 0.97809218  1.6089627   1.6089627   1.09156913  1.00297245 -1.33410274]
#  [-0.57284357  0.6587859   0.6587859  -1.36933384 -0.25265831 -0.13954076]
#  ...
#  [-0.57284357  0.1836975   0.1836975  -0.13888236 -0.25265831 -0.73682175]
#  [ 0.97809218  1.3714185   1.3714185   1.09156913  1.00297245 -1.33410274]
#  [-0.57284357  1.6089627   1.6089627  -1.36933384 -0.25265831  0.09937163]]

# %%
x=pd.DataFrame(x)
#convert the standardized numpy array 'x' back to a pandas DataFrame.
#this allows us to retain DataFrame and structure and use column names.

# %%
x.head()
#display the first five rows of the datasets
# Out:
#           0         1         2         3         4         5
# 0 -0.572844 -0.766479 -0.766479 -1.369334 -0.252658 -0.139541
# 1  0.978092  1.608963  1.608963  1.091569  1.002972 -1.334103
# 2 -0.572844  0.658786  0.658786 -1.369334 -0.252658 -0.139541
# 3  0.978092 -0.291391 -0.291391  1.091569 -1.508289 -0.020085
# 4 -0.572844  0.421242  0.421242  1.091569 -0.252658  1.293934

# %%
print(type(x))
#display the type of 'x' column.
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
test.head()
#display the first five rows of the 'train' Dataframe.
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 1         0.007565         13
# 1             1067     8.300000                 4         0.038428          4
# 2             1406    14.600000                 1         0.099575         11
# 3              809     7.315000                 1         0.015388         13
# 4             1184    12.695633                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type
# ...

# %%
test['Outlet_Age']=test['Outlet_Establishment_Year'].apply(lambda year: 2024-year)
#calculate the age of each outlet by subtracting the establishment year from 2024.
#And add it as a new column 'Outlet_Age' to the DataFrame.

# %%
test.head()
#display the first five rows of the 'train' Dataframe.
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0             1103    20.750000                 1         0.007565         13
# 1             1067     8.300000                 4         0.038428          4
# 2             1406    14.600000                 1         0.099575         11
# 3              809     7.315000                 1         0.015388         13
# 4             1184    12.695633                 2         0.118599          4
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622                  9                       1999          1.0
# 1   87.3198                  2                       2007          3.0
# 2  241.7538                  0                       1998          3.0
# 3  155.0340                  2                       2007          3.0
# 4  234.2300                  5                       1985          1.0
#
#    Outlet_Location_Type  Outlet_Type  Outlet_Age
# ...

# %%
test=test.drop(['Item_Identifier','Item_Weight','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size'],axis=1)
#Remove the specified columns from the 'train' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
test=test.drop(['Item_Visibility'],axis=1)
#Remove the specified columns from the 'train' DataFrame.
#These columns are removed as they are not neccessary for the current analysis or modelling.

# %%
test.head()
#display the first five rows of the 'train' Dataframe.
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 1         13  107.8622                     0            1
# 1                 4          4   87.3198                     1            1
# 2                 1         11  241.7538                     2            0
# 3                 1         13  155.0340                     1            1
# 4                 2          4  234.2300                     2            3
#
#    Outlet_Age
# 0          25
# 1          17
# 2          26
# 3          17
# 4          39

# %%
from sklearn.preprocessing import StandardScaler
#import standardscaler from sklearn.preprocessing for feature standardization.
#standardscaler will be used to standardize features by removing the mean and scaling to unit variation.

# %%
x_test=test[['Item_Fat_Content','Item_Type','Outlet_Type','Outlet_Age']]
y_test=test['Outlet_Location_Type']
#define the feature variable (x) and the target variable (y) for the model.
#'x' contains the columns 1,2,3,4 and 6.
#'y' contains the column 5 which is the variable we want to predict.

# %%
x_test.shape
#display the dimensions of the 'x' DataFrame.
# Out:
# (5681, 4)

# %%
scaler=StandardScaler()
#create an instance of standardscaler for feature standardiztion.
#this scaler will be used to normalize the features by removing the mean and scaling to unit variance.

# %%
x_test=scaler.fit_transform(x)
#standardize the feature variable 'x' using the standardscaler.
#this scales the feature to have a mean of 0 and a standard deviation of 1.

# %%
print(type(x_test))
#display the type of'x' coumn.
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(x_test)
#display the 'x'.
# Out:
#              0         1         2         3         4         5
# 0    -0.572844 -0.766479 -0.766479 -1.369334 -0.252658 -0.139541
# 1     0.978092  1.608963  1.608963  1.091569  1.002972 -1.334103
# 2    -0.572844  0.658786  0.658786 -1.369334 -0.252658 -0.139541
# 3     0.978092 -0.291391 -0.291391  1.091569 -1.508289 -0.020085
# 4    -0.572844  0.421242  0.421242  1.091569 -0.252658  1.293934
# ...        ...       ...       ...       ...       ...       ...
# 8518 -0.572844  1.371418  1.371418  1.091569 -0.252658  1.293934
# 8519  0.978092 -1.716656 -1.716656 -0.138882 -0.252658 -0.497909
# 8520 -0.572844  0.183698  0.183698 -0.138882 -0.252658 -0.736822
# 8521  0.978092  1.371418  1.371418  1.091569  1.002972 -1.334103
# 8522 -0.572844  1.608963  1.608963 -1.369334 -0.252658  0.099372
#
# [8523 rows x 6 columns]

# %%
x_test=pd.DataFrame(x)
#convert the standardized numpy array 'x' back to a pandas DataFrame.
#this allows us to retain DataFrame and structure and use column names

# %%
x_test.head()
#display the first five rows of the Datasets.
# Out:
#           0         1         2         3         4         5
# 0 -0.572844 -0.766479 -0.766479 -1.369334 -0.252658 -0.139541
# 1  0.978092  1.608963  1.608963  1.091569  1.002972 -1.334103
# 2 -0.572844  0.658786  0.658786 -1.369334 -0.252658 -0.139541
# 3  0.978092 -0.291391 -0.291391  1.091569 -1.508289 -0.020085
# 4 -0.572844  0.421242  0.421242  1.091569 -0.252658  1.293934

# %% [markdown]
# #MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
#for evaluating the model using metrics
from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.model_selection import cross_val_score as CVS

# %%
# Define the linear regression model
lr = LinearRegression()

# Train the model on the training data
lr.fit(x, y)

# Precting the model using the test set
y_predict = lr.predict(x)

# Evaluating the training set with the metric values

print("R-Square value on the training set: = ", lr.score(x,y))
print("----------------------------------------------------------------------------------------------")

# Use cross-validation to get the R-squared score
scores = CVS(lr, x, y, cv=5)
print('CV R-squared scores:', scores,"\n")
print('Average CV R-squared score:', np.mean(scores),"\n")
# Out:
# R-Square value on the training set: =  0.24240716005731944
# ----------------------------------------------------------------------------------------------
# CV R-squared scores: [0.23518817 0.24435164 0.22868834 0.22671096 0.26974673]
#
# Average CV R-squared score: 0.2409371698546919

# %%
import pickle
#import the pickel for serializing and deserializing python objects.

# %%
Bigmart= "BigMart_Analysis.sav"
#define the filename for saving the model.
pickle.dump(lr, open(Bigmart,'wb'))
#serialize the trained model'lr' and save it to the file'Bigmart_Analysis.sav'.

# %% [markdown]
# #SUMMARY

# %% [markdown]
# The Big Mart analysis project leverages machine learning to optimize sales forecasting by systematically processing and analyzing data. The process begins with
#
#
# 1.Loading of Data:
# The project begins by importing the dataset, ensuring that all relevant information is accessible and organized.
#
# 2.Data Structures and Content:
# Data is structured with product details, sales figures, and categorical variables for comprehensive analysis.
#
# 3.Data Preprocessing:
# Cleans and prepares data by addressing inconsistencies, missing values, and redundant information for accuracy.
#
# 4.Univariate Analysis:
# Analyzes individual variables to understand their distribution, central tendency, and variability within the dataset.
#
# 5.Handling Missing and Categorical Values:
# Imputes missing values and encodes categorical variables to ensure accurate and reliable model input.
#
# 6.Handling the Outliers:
# Identifies and manages outliers to reduce their impact and improve the model’s performance and accuracy.
#
# 7.Cube Transformation:
# Applies transformation techniques to stabilize variance and normalize data distributions for better analysis.
#
# 8.Bivariate Analysis:
# Examines relationships between pairs of variables to uncover significant correlations and dependencies.
#
# 9.Feature Engineering:
# Develops and modifies features to enhance the model’s ability to predict sales effectively.
#
# 10.Model Building:
# Constructs and fine-tunes machine learning models to accurately forecast sales and optimize predictions.
